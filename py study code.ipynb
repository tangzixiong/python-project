# %%
d=iter([1,2,3,4])
next(d)
# Out:
# 1

# %%
next(d)
# Out:
# 2

# %%
next(d)
# Out:
# 3

# %%
next(d)
# Out:
# 4

# %%
next(d)
# Out:
# 2

# %%
next(d)
# Out:
# (3, 4)

# %%
d=iter('abc')

# %%
next(d)
# Out:
# 'a'

# %%
next(d)
# Out:
# 'b'

# %%
next(d)
# Out:
# 'c'

# %%
d=iter({'name':'jhon','age':'25'})

next(d)
# Out:
# 'name'

# %%
next(d)
# Out:
# 'age'

# %%
import time
now = time.time()
print(now)
# Out:
# 1676206776.5141456

# %%
import time
now = time.asctime(time.localtime())
print(now)
# Out:
# Sun Feb 12 21:10:47 2023
